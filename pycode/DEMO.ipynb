# %%
# %%capture --no-display
pip install -r requirements.txt

# %%
exec(open('DEMOsetup.py').read())
# Out:
# setup loaded
#
# Formatted .vtt file saved as 'data/formatted_output.vtt'.

# %%
create_stats_figure(df)
create_timeline_figure(df)

# %% [markdown]
# EXTRACTIVE SUMMARIZATION
# adjust the desired number of sentences in the summary

# %%
for item in items:
    wrapped_text = textwrap.fill(item, width=100)
    print(wrapped_text)
    print()
# Out:
# Our team has been working overtime to resolve these issues, but we are still a week behind schedule
#
#  The documentation wasn't as thorough as we expected, and we've had to do a lot of troubleshooting
# to get things working
#
#  Moving on to the finance update, Michael, can you brief us on the current budget status? John, can
# your team cut down on overtime and find a more efficient way to address the issues? What can we do
# to improve our customer support response time?

# %%
# ax = abstractive_summarize_chunks(chunks)
print(textwrap.fill(summary_text, width=100))
# Out:
# The team is still a week behind schedule due to unexpected bugs in the code. The team is considering
# hiring additional support staff to handle the volume of inquiries. The recent workload and overtime
# seem to be taking a toll on everyone.

# %%
ai = summarize_text(text)
print(textwrap.fill(ai, width=100))
# Out:
# The meeting started with a project update, where the development team reported delays due to bugs in
# the code. The marketing team saw success in campaigns but noted a low conversion rate. The finance
# team raised concerns about budget overruns due to development costs. Customer feedback highlighted
# issues with response time in customer support. Plans were discussed to address these issues,
# including A/B testing landing pages, hiring additional support staff, and implementing a chatbot.
# Lastly, concerns about team morale were raised, leading to plans for a team-building activity and
# stress management resources. The meeting concluded with a reminder to send department reports by the
# next day.

# %%
utility = utility_text(text)
print(utility)
# Out:
# Key Points:
# 1. Development progress is behind schedule due to unexpected bugs in the code, specifically related to the integration of a new API.
# 2. Marketing strategy has seen success in increasing website traffic, but conversion rates are lower than expected.
# 3. Finance update includes concerns about budget overruns, particularly in the development team due to overtime and additional resources needed to fix bugs.
# 4. Customer feedback is positive overall, but there are complaints about the response time of customer support.
# 5. Team morale is low due to recent workload and conflicts between team members.
#
# Key Decisions:
# 1. Development team to reassess approach to managing workload and streamline process to avoid relying on overtime.
# 2. Marketing team to A/B test landing pages and enhance email marketing campaigns to improve conversion rates.
# 3. Finance team to find ways to control expenses and avoid budget overruns, specifically in the development team.
# ...

# %%
senti = sentiment(df)
print(senti)
# Out:
# ["!!!: Who talks about stakeholders? She has ruined Julius and Venu all mentioned stakeholders, who clearly is a topic that's important, you know, and we talked about conflict. General talked about conflict. So, you know, gives you a way to navigate and get some sense of what we're talking about.\n\n", "!!!: You can see where this is going and it's tagged properly, so the tagging methods so you see that I ask you, can you put this in the box? So can you move that box? Because if it is in one box, it will absorb the tag. Think about the work that we do reference mapping standard mappings for any data managing or P&L V PSHIP mapping. This is an analogy of that because if you don't have a good mapping, you can't do these kind of things. If you can take this kind of information.\n\n", "!!!: And you tell people one idea per sticky. You remember I said that because if you don't do that, then you get more than one idea and sticky. Think about that from a perspective of data quality. People 
# ...
